# %%
import pandas as pd
from sklearn.model_selection import train_test_split

dataset=pd.read_csv("Naive-Bayes-Classification-Data.csv")
dataset.head(3)
# Out:
#    glucose  bloodpressure  diabetes
# 0       40             85         0
# 1       40             92         0
# 2       45             63         1

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
dataset.shape
# Out:
# (995, 3)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import tensorflow
from keras.layers import Dense, Input
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %%
ann=Sequential()

ann.add(Input(shape=(2,)))
ann.add(Dense(3,activation="relu"))
ann.add(Dense(2,activation="relu"))
ann.add(Dense(1,activation="sigmoid"))

ann.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
ann.fit(x_train,y_train,batch_size=1,epochs=20,callbacks=EarlyStopping())
# Out:
# Epoch 1/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6997 - loss: 1.0134
# Epoch 2/20
# 151/796 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7613 - loss: 0.5992
# /home/78903a55-b1b9-4cbd-b726-90462af350cf/.local/lib/python3.12/site-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7538 - loss: 0.6000
# Epoch 3/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7487 - loss: 0.5664
# Epoch 4/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7450 - loss: 0.5554
# Epoch 5/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7450 - loss: 0.5604
# Epoch 6/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7412 - loss: 0.5515
# Epoch 7/20
# 796/796 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7538 - loss: 0.5465
# ...

# %%
from sklearn.metrics import accuracy_score

prd=ann.predict(x_test)
pp=[]
for i in prd:
    if i[0]>0.5:
        pp.append(1)
    else:
        pp.append(0)
accuracy_score(y_test,pp)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 0.7788944723618091

# %%
import numpy as np

a=ann.predict(np.array([[40,92]], dtype=int))

pp1=[]
for i in a:
    if i[0]>0.5:
        pp1.append(1)
    else:
        pp1.append(0)
pp1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [0]
